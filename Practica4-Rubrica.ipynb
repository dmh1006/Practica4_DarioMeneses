# %% [markdown]
# <img style="float:left" width="30%" src="pics/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="8%" src="pics/PythonLogo.svg">
# <br style="clear:both;">
#
# # Sistemas Inteligentes aplicados en Salud
#
# <h2 style="display: inline-block; padding: 4mm; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">Práctica IV: Optimización de rutas asistenciales en entornos hospitalarios mediante algoritmos genéticos</h2>
# <br style="clear:both;">
# <h2 style="display: inline-block; padding: 4mm; padding-left:; background-color: orange; line-height: 1.3em; color: white; border-radius: 10px;">Requisitos y rúbrica de calificación</h2>
#
# ## Docente
#
#  - **David García García**

# %% [markdown]
# ## Porcentaje de calificación total
#
# La Práctica 4 (**Optimización de rutas asistenciales en entornos hospitalarios mediante algoritmos genéticos**) tendrá un peso del **25%** en el total de la calificación de la parte de prácticas de la asignatura y realizará de forma **individual**.

# %% [markdown]
# ### IMPORTANTE
# - Emplea la plantilla de repositorio de proyecto proporcionada de acuerdo a las características de la práctica.
# - Solo se evaluará y calificará lo entregado en el repositorio.
# - Todas las funciones implementadas deben estar correctamente documentadas.
#
#
# ## Documentos a entregar
#
# - Repositorio **GitHub** privado compartido con `davgarciagarcia` con los archivos y carpetas necesarios para comprobar el correcto funcionamiento de los implementado.
#   - Un notebook específico para la ejecución y obtención de resultados de cada uno de los ejercicios propuestas.
#   - Archivos `.py` en el que se incluyan las diferentes funciones o clases implementadas y que tengan que ser empleadas en los diferentes notebooks.
#   - Archivos de configuración de proyecto y de git: .gitignore, README.md, requirements.txt...
# - En el **buzón de entrega** del aula virtual, se incluirá un documento pdf que contenga:
#   - Enlace al repositorio privado
#   - Manual de explicación para la correcta ejecución y de los diferentes notebooks implementados.
#   - Resultados obtenidos en cada una de las partes en las que se soliciten explicaciones o justificaciones.
#   - Planificación y ejecución
#
# <div class="alert alert-warning"> El codigo implementado debe ir correctamente comentado de forma que se entienda perfectamente el motivo del desarrollo de cada función, clase o estructura así como la justificación de su funcionamiento. Se podrá penalizar hasta el <kdb>30%</kdb> de la calificación sino aparece ningún comentario en el código entregado.</div>
#
# <div class="alert alert-warning"> Se podrá penalizar hasta el <kdb>10%</kdb> de la calificación si el repositorio compartido no cumple con los mínimos exigidos.</div>
#
#
# ### `FUNDAMENTAL`
#
# Antes de realizar la entrega, comprueba que en el repositorio se encuentra todo correctamente incluido y realiza todos los test necesarios (creación de entorno virtual, instalación de paquetes, ejecución de scripts, configuración de módulos...)
#
# ------------------
#
# ## Fecha de entrega
#
# - La fecha límite para la entrega de los documentos de la Práctica 4 será el **8 de enero de 2026** a las 14:00h.
# - Todos aquellos archivos que no se entreguen de la manera indicada dentro de los límites temporales establecidos, no se serán evaluados ni calificados.
# - Si no se comparte el repositorio antes de la fecha límite, la calificación será de 0.
# - No se tendrán en cuenta las modificaciones realizadas en el repositorio de GitHub más allá de la fecha y hora límite.
# ------------------

# %% [markdown]
# ## Rúbrica de Evaluación
#
# Para la valoración del código entregado, se realizará una descarga del repositorio proporcionado y se seguirán las instrucciones proporcionadas en el README.md para la creación del entorno virtual y la instalación de los paquetes.
#
# > **Total: 10 puntos (25 % de la calificación final de prácticas)**
#
# ##  Ejercicio 1: Caso clínico-simulado
#
# | **Criterio de evaluación** | **Excelente (100 %)** | **Aceptable (60–40 %)** | **Insuficiente (0 %)** | **Puntos (máx.)** |
# |-----------------------------|------------------------|---------------------------|---------------------------|-------------------|
# | **1. Implementación del algoritmo genético (DEAP)** | Código funcional, modular y correctamente documentado. Operadores definidos y evaluación coherente del recorrido médico. | Código operativo pero con simplificaciones o errores leves. | Código incompleto o sin funcionamiento. | 1,2 |
# | **2. Configuraciones y justificación experimental** | ≥3 configuraciones distintas con justificación razonada de los parámetros (cruce, mutación, selección). | Configuraciones mínimas o justificación superficial. | Configuraciones insuficientes o sin justificar. | 0,9 |
# | **3. Análisis de resultados y comparación** | Comparativa completa (fitness, convergencia, coste, tiempo) con tablas y gráficos. | Comparativa parcial o análisis limitado. | Resultados numéricos sin análisis. | 0,9 |
# | **4. Visualización y presentación** | Gráficos legibles, mapa con mejor ruta, estructura clara. | Visualización básica o poco clara. | Sin gráficos o mapa final. | 0,5 |
# | **5. Discusión crítica del comportamiento del algoritmo** | Análisis profundo de la influencia de parámetros, estabilidad y convergencia. Interpretación contextualizada en la planificación médica. | Discusión general o poco profunda. | Sin discusión ni interpretación. | 1,0 |
# | **TOTAL EJERCICIO 1** | — | — | — | **4,5** |
#
#
# ##  Ejercicio 2: Planificación logística automatizada
#
# | **Criterio de evaluación** | **Excelente (100 %)** | **Aceptable (60–40 %)** | **Insuficiente (0 %)** | **Puntos (máx.)** |
# |-----------------------------|------------------------|---------------------------|---------------------------|-------------------|
# | **1. Implementación del algoritmo genético (DEAP)** | Código funcional y modular. Operadores correctamente definidos y adaptados al problema logístico. | Código operativo pero con simplificaciones o errores leves. | Código incompleto o sin funcionamiento. | 1,2 |
# | **2. Configuraciones y justificación experimental** | ≥3 configuraciones distintas y justificadas en cuanto a operadores y parámetros. | Configuraciones mínimas o justificación superficial. | Configuraciones insuficientes o sin justificar. | 0,9 |
# | **3. Análisis de resultados y comparación** | Comparativa completa (fitness, convergencia, coste, estabilidad) con tablas y gráficos. | Comparativa parcial o análisis limitado. | Resultados numéricos sin análisis. | 0,9 |
# | **4. Visualización y presentación** | Gráficos de convergencia y mapa con la mejor ruta. Presentación clara y ordenada. | Visualización básica o poco comentada. | Sin gráficos o visualización de la ruta. | 0,5 |
# | **5. Discusión crítica del comportamiento del algoritmo** | Análisis fundamentado sobre la influencia de los operadores y la estabilidad. Conexión con el contexto de logística hospitalaria. | Discusión general o poco profunda. | Sin discusión ni interpretación. | 1,0 |
# | **TOTAL EJERCICIO 2** | — | — | — | **4,5** |
#
#
# ## Criterio global de la práctica
#
# | **Aspecto global** | **Excelente (100 %)** | **Aceptable (60-40 %)** | **Insuficiente (0 %)** | **Puntos (máx.)** |
# |---------------------|------------------------|---------------------------|---------------------------|-------------------|
# | **Calidad del informe y presentación final** | Informe completo, estructurado y coherente. Incluye tablas, gráficos y análisis claros. Redacción científica precisa. | Informe correcto pero con deficiencias menores de estructura o claridad. | Informe incompleto, desordenado o con análisis insuficiente. | 1,0 |

# %% [markdown]
# ### 🎖 `Bonificación (0.5 ptos)`: Solución más eficiente del ejercicio 1 de entre todos los alumnos.
